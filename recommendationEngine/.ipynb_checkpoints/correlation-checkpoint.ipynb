# %%
import numpy as np
import pandas as pd
from util import *

# %%
def cosine_similarity(list1, list2):
        dotprod = 0
        betrag_x = 0
        betrag_y = 0
        for i in range(0,len(list1)):
            x=list1[i]
            y=list2[i]
            dotprod+=x*y
            betrag_x+=x*x
            betrag_y+=y*y
        return dotprod/((betrag_x*betrag_y)**(1/2.0)) if betrag_x != 0 and betrag_y != 0 else 0

def give_recommendation_based_on_correlation_matrix(matrix, fingerprinting_vector):
    cos_sim_list = [{"id":x,"sim":cosine_similarity(matrix[x],fingerprinting_vector)} for x in range(0, len(matrix))]
    cos_sim_list.sort(key = lambda x: x["sim"], reverse=True)
    recommendation = recommendations[cos_sim_list[0]["id"]]
    return recommendation

# %%
df = pd.DataFrame(np.random.rand(150,len(fingerprinting_metrics)), columns=fingerprinting_metrics)
df
# Out:
#      Average Throughput Rate   Average Lead Time for User Story   \
# 0                    0.379975                           0.893063
# 1                    0.117617                           0.313686
# 2                    0.187721                           0.360067
# 3                    0.158738                           0.988420
# 4                    0.875645                           0.546871
# ..                        ...                                ...
# 145                  0.629347                           0.648760
# 146                  0.699009                           0.363002
# 147                  0.927469                           0.248661
# 148                  0.097408                           0.950892
# 149                  0.954573                           0.195016
#
#      Average Cycle Time for User Story   Average Wait Time for User Story   \
# 0                              0.016876                           0.547785
# 1                              0.703464                           0.938548
# 2                              0.314391                           0.518821
# 3                              0.188884                           0.979928
# 4                              0.942359                           0.166274
# ..                                  ...                                ...
# 145                            0.431498                           0.048893
# 146                            0.608967                           0.013290
# 147                            0.805686                           0.944539
# 148                            0.434899                           0.273746
# 149                            0.563263                           0.726887
#
#      Amount of WIP   Average Repository Activity   Average Pull Request Size   \
# 0          0.086195                      0.099256                    0.276041
# 1          0.558001                      0.491532                    0.126450
# 2          0.352522                      0.600092                    0.234122
# 3          0.758915                      0.283366                    0.775372
# 4          0.642098                      0.419629                    0.078844
# ..              ...                           ...                         ...
# 145        0.437622                      0.243976                    0.857104
# 146        0.389981                      0.824989                    0.834146
# 147        0.439125                      0.134059                    0.553909
# 148        0.086150                      0.555807                    0.034888
# 149        0.346686                      0.974921                    0.140731
#
#      Build Frequency   Average Time to Fix Broken Build   \
# 0            0.957018                           0.443958
# 1            0.025927                           0.633108
# 2            0.459313                           0.608453
# 3            0.669959                           0.169412
# 4            0.706464                           0.544556
# ..                ...                                ...
# 145          0.926557                           0.377396
# 146          0.995136                           0.971573
# 147          0.294022                           0.693578
# 148          0.326183                           0.101579
# 149          0.916303                           0.631543
#
#      Average Build Execution Time   ...  Average Pull Request Lead Time   \
# 0                         0.944336  ...                         0.362870
# 1                         0.647951  ...                         0.697309
# 2                         0.468424  ...                         0.941909
# 3                         0.491021  ...                         0.174758
# 4                         0.934640  ...                         0.966970
# ..                             ...  ...                              ...
# 145                       0.822225  ...                         0.437050
# 146                       0.169881  ...                         0.821153
# 147                       0.554454  ...                         0.007615
# 148                       0.877018  ...                         0.915592
# 149                       0.943466  ...                         0.213225
#
#      Average Code Review Time   Average Pull Request Time to First Review   \
# 0                     0.836003                                    0.840807
# 1                     0.915316                                    0.243466
# 2                     0.820082                                    0.760558
# 3                     0.264485                                    0.946744
# 4                     0.897887                                    0.901057
# ..                         ...                                         ...
# 145                   0.931680                                    0.523310
# 146                   0.332741                                    0.363416
# 147                   0.995910                                    0.081929
# 148                   0.248687                                    0.124416
# 149                   0.892361                                    0.261105
#
#      Average Pull Request Last Review to Merge Time   Pull Request Flow Ratio  \
# 0                                           0.049687                 0.917653
# 1                                           0.714299                 0.575168
# 2                                           0.769838                 0.994982
# 3                                           0.899322                 0.254659
# 4                                           0.979984                 0.258993
# ..                                               ...                      ...
# 145                                         0.105522                 0.650079
# 146                                         0.507757                 0.522090
# 147                                         0.215613                 0.576259
# 148                                         0.069024                 0.370502
# 149                                         0.955458                 0.279103
#
#      Pull Request Engagement  Deployment Volume  Average Deployment Duration  \
# 0                   0.348791           0.453165                     0.758890
# 1                   0.028287           0.353625                     0.529983
# 2                   0.123741           0.757098                     0.522323
# 3                   0.207307           0.446430                     0.535928
# 4                   0.075084           0.019225                     0.975817
# ..                       ...                ...                          ...
# 145                 0.056947           0.807030                     0.862246
# 146                 0.810625           0.795249                     0.244872
# 147                 0.667681           0.578423                     0.675320
# 148                 0.753883           0.530452                     0.970238
# 149                 0.158627           0.586511                     0.305521
#
#      Deployment Failure Rate  Pull Request/Deployment Ratio
# 0                   0.895446                       0.449831
# 1                   0.574735                       0.744900
# 2                   0.957371                       0.749962
# 3                   0.109710                       0.637266
# 4                   0.569543                       0.814241
# ..                       ...                            ...
# 145                 0.001900                       0.593890
# 146                 0.568989                       0.728315
# 147                 0.037435                       0.689806
# 148                 0.341276                       0.167700
# 149                 0.200386                       0.613549
#
# [150 rows x 27 columns]

# %%
matrix = np.asmatrix(np.random.rand(len(recommendations),len(fingerprinting_metrics)))
matrix_df = pd.DataFrame(matrix, index = recommendations, columns = fingerprinting_metrics)
# for x in fingerprinting_metrics:
#     for y in recommendations:
#         matrix_df.loc[y,x]=1 if y == "Take fewer requests in the Product Backlog" else 0
matrix_df
# Out:
#                                                     Average Throughput Rate   \
# Take fewer requests in the Product Backlog                          0.793203
# Finish old user stories first                                       0.602771
# Refine user stories before adding to backlog                        0.534937
# Formulate and estimate user stories better                          0.730133
# Check skills/capacity of developers                                 0.088414
# plan more developers for the user story                             0.990498
# Refine user stories before adding to backlog                        0.185002
# Review planning process                                             0.494983
# Take fewer requests in the Product Backlog                          0.017256
# Check skills/capacity of developers                                 0.459839
# plan more developers for the user story                             0.306567
# Prune and keep product backlog clean: review ne...                  0.969124
# Decrease number of WIPs to under …                                  0.180695
# Formulate and estimate user stories better                          0.797545
# Check skills/capacity of developers                                 0.066169
# Check foundational processes, platforms and aut...                  0.992092
# Use Git more actively                                               0.098664
# Plan smaller tasks (<1 day) and PRs                                 0.928477
# Prioritize fixing broken build                                      0.429051
# Optimize build / test time                                          0.850614
# Run static code analysis on daily basis                             0.328085
# Integrate code more frequently                                      0.696254
# Write more unit tests                                               0.241329
# Act to prevent broken builds                                        0.345349
# Take care of reported defects quickly                               0.991736
# Increase capacity of the team                                       0.648870
# Check the change integration process: automated...                  0.732856
# Prioritize code review                                              0.228145
# Plan more reviewers                                                 0.119137
# Keep PR WIP stable to avoid PR saturation                           0.208517
# Investigate impediments against deployment proc...                  0.211067
# Align team discussions, don’t waste too much ti...                  0.148301
# Foster the culture of code review                                   0.167664
# Try to optimize deployment time                                     0.929499
# Investigate deployment pipeline                                     0.530061
# Deploy PRs more often                                               0.835696
#
#                                                     Average Lead Time for User Story   \
# Take fewer requests in the Product Backlog                                   0.687561
# Finish old user stories first                                                0.811627
# Refine user stories before adding to backlog                                 0.793109
# Formulate and estimate user stories better                                   0.432932
# Check skills/capacity of developers                                          0.228473
# plan more developers for the user story                                      0.715191
# Refine user stories before adding to backlog                                 0.442951
# Review planning process                                                      0.999678
# Take fewer requests in the Product Backlog                                   0.355006
# Check skills/capacity of developers                                          0.747052
# plan more developers for the user story                                      0.773674
# Prune and keep product backlog clean: review ne...                           0.978005
# Decrease number of WIPs to under …                                           0.515836
# Formulate and estimate user stories better                                   0.366576
# Check skills/capacity of developers                                          0.186359
# Check foundational processes, platforms and aut...                           0.848590
# Use Git more actively                                                        0.787076
# Plan smaller tasks (<1 day) and PRs                                          0.148275
# Prioritize fixing broken build                                               0.881541
# Optimize build / test time                                                   0.248731
# Run static code analysis on daily basis                                      0.978444
# Integrate code more frequently                                               0.284962
# Write more unit tests                                                        0.651859
# Act to prevent broken builds                                                 0.815204
# Take care of reported defects quickly                                        0.775716
# Increase capacity of the team                                                0.989055
# Check the change integration process: automated...                           0.570263
# Prioritize code review                                                       0.092302
# Plan more reviewers                                                          0.850452
# Keep PR WIP stable to avoid PR saturation                                    0.096924
# Investigate impediments against deployment proc...                           0.630225
# Align team discussions, don’t waste too much ti...                           0.162998
# Foster the culture of code review                                            0.584557
# Try to optimize deployment time                                              0.768216
# Investigate deployment pipeline                                              0.823989
# Deploy PRs more often                                                        0.947897
#
#                                                     Average Cycle Time for User Story   \
# Take fewer requests in the Product Backlog                                    0.695460
# Finish old user stories first                                                 0.457946
# Refine user stories before adding to backlog                                  0.753422
# Formulate and estimate user stories better                                    0.567915
# Check skills/capacity of developers                                           0.304577
# plan more developers for the user story                                       0.267872
# Refine user stories before adding to backlog                                  0.559928
# Review planning process                                                       0.338361
# Take fewer requests in the Product Backlog                                    0.186955
# Check skills/capacity of developers                                           0.274276
# plan more developers for the user story                                       0.037511
# Prune and keep product backlog clean: review ne...                            0.969588
# Decrease number of WIPs to under …                                            0.349199
# Formulate and estimate user stories better                                    0.194275
# Check skills/capacity of developers                                           0.180075
# Check foundational processes, platforms and aut...                            0.480824
# Use Git more actively                                                         0.259397
# Plan smaller tasks (<1 day) and PRs                                           0.661091
# Prioritize fixing broken build                                                0.042895
# Optimize build / test time                                                    0.784123
# Run static code analysis on daily basis                                       0.872619
# Integrate code more frequently                                                0.517694
# Write more unit tests                                                         0.441974
# Act to prevent broken builds                                                  0.801464
# Take care of reported defects quickly                                         0.187229
# Increase capacity of the team                                                 0.907594
# Check the change integration process: automated...                            0.994049
# Prioritize code review                                                        0.036576
# Plan more reviewers                                                           0.075565
# Keep PR WIP stable to avoid PR saturation                                     0.427314
# Investigate impediments against deployment proc...                            0.960362
# Align team discussions, don’t waste too much ti...                            0.812015
# Foster the culture of code review                                             0.351661
# Try to optimize deployment time                                               0.528178
# Investigate deployment pipeline                                               0.261022
# Deploy PRs more often                                                         0.487597
#
#                                                     Average Wait Time for User Story   \
# Take fewer requests in the Product Backlog                                   0.147667
# Finish old user stories first                                                0.355883
# Refine user stories before adding to backlog                                 0.274233
# Formulate and estimate user stories better                                   0.778697
# Check skills/capacity of developers                                          0.440308
# plan more developers for the user story                                      0.060513
# Refine user stories before adding to backlog                                 0.353017
# Review planning process                                                      0.719491
# Take fewer requests in the Product Backlog                                   0.634058
# Check skills/capacity of developers                                          0.478542
# plan more developers for the user story                                      0.274156
# Prune and keep product backlog clean: review ne...                           0.324207
# Decrease number of WIPs to under …                                           0.702154
# Formulate and estimate user stories better                                   0.683000
# Check skills/capacity of developers                                          0.334112
# Check foundational processes, platforms and aut...                           0.416431
# Use Git more actively                                                        0.182516
# Plan smaller tasks (<1 day) and PRs                                          0.398341
# Prioritize fixing broken build                                               0.830800
# Optimize build / test time                                                   0.707235
# Run static code analysis on daily basis                                      0.585232
# Integrate code more frequently                                               0.392740
# Write more unit tests                                                        0.391261
# Act to prevent broken builds                                                 0.727549
# Take care of reported defects quickly                                        0.865087
# Increase capacity of the team                                                0.871142
# Check the change integration process: automated...                           0.994822
# Prioritize code review                                                       0.734719
# Plan more reviewers                                                          0.605334
# Keep PR WIP stable to avoid PR saturation                                    0.531525
# Investigate impediments against deployment proc...                           0.423218
# Align team discussions, don’t waste too much ti...                           0.277153
# Foster the culture of code review                                            0.228210
# Try to optimize deployment time                                              0.415650
# Investigate deployment pipeline                                              0.600530
# Deploy PRs more often                                                        0.419946
#
#                                                     Amount of WIP   \
# Take fewer requests in the Product Backlog                0.870439
# Finish old user stories first                             0.744095
# Refine user stories before adding to backlog              0.892408
# Formulate and estimate user stories better                0.737049
# Check skills/capacity of developers                       0.789767
# plan more developers for the user story                   0.980880
# Refine user stories before adding to backlog              0.506296
# Review planning process                                   0.914047
# Take fewer requests in the Product Backlog                0.589634
# Check skills/capacity of developers                       0.723281
# plan more developers for the user story                   0.668642
# Prune and keep product backlog clean: review ne...        0.529932
# Decrease number of WIPs to under …                        0.407452
# Formulate and estimate user stories better                0.950014
# Check skills/capacity of developers                       0.958665
# Check foundational processes, platforms and aut...        0.914532
# Use Git more actively                                     0.091458
# Plan smaller tasks (<1 day) and PRs                       0.695484
# Prioritize fixing broken build                            0.770213
# Optimize build / test time                                0.816556
# Run static code analysis on daily basis                   0.831151
# Integrate code more frequently                            0.142973
# Write more unit tests                                     0.083780
# Act to prevent broken builds                              0.850804
# Take care of reported defects quickly                     0.168244
# Increase capacity of the team                             0.203008
# Check the change integration process: automated...        0.004653
# Prioritize code review                                    0.876210
# Plan more reviewers                                       0.451056
# Keep PR WIP stable to avoid PR saturation                 0.967667
# Investigate impediments against deployment proc...        0.116199
# Align team discussions, don’t waste too much ti...        0.478772
# Foster the culture of code review                         0.211453
# Try to optimize deployment time                           0.984255
# Investigate deployment pipeline                           0.486828
# Deploy PRs more often                                     0.693835
#
#                                                     Average Repository Activity   \
# Take fewer requests in the Product Backlog                              0.136027
# Finish old user stories first                                           0.147752
# Refine user stories before adding to backlog                            0.310173
# Formulate and estimate user stories better                              0.520524
# Check skills/capacity of developers                                     0.371385
# plan more developers for the user story                                 0.917470
# Refine user stories before adding to backlog                            0.629314
# Review planning process                                                 0.736135
# Take fewer requests in the Product Backlog                              0.457133
# Check skills/capacity of developers                                     0.584478
# plan more developers for the user story                                 0.658297
# Prune and keep product backlog clean: review ne...                      0.811636
# Decrease number of WIPs to under …                                      0.944925
# Formulate and estimate user stories better                              0.050482
# Check skills/capacity of developers                                     0.517380
# Check foundational processes, platforms and aut...                      0.763392
# Use Git more actively                                                   0.800602
# Plan smaller tasks (<1 day) and PRs                                     0.778832
# Prioritize fixing broken build                                          0.716849
# Optimize build / test time                                              0.924672
# Run static code analysis on daily basis                                 0.392942
# Integrate code more frequently                                          0.509326
# Write more unit tests                                                   0.023998
# Act to prevent broken builds                                            0.091583
# Take care of reported defects quickly                                   0.158235
# Increase capacity of the team                                           0.179834
# Check the change integration process: automated...                      0.183490
# Prioritize code review                                                  0.082770
# Plan more reviewers                                                     0.622996
# Keep PR WIP stable to avoid PR saturation                               0.044506
# Investigate impediments against deployment proc...                      0.735366
# Align team discussions, don’t waste too much ti...                      0.819735
# Foster the culture of code review                                       0.480465
# Try to optimize deployment time                                         0.776947
# Investigate deployment pipeline                                         0.534084
# Deploy PRs more often                                                   0.005180
#
#                                                     Average Pull Request Size   \
# Take fewer requests in the Product Backlog                            0.340187
# Finish old user stories first                                         0.209096
# Refine user stories before adding to backlog                          0.366878
# Formulate and estimate user stories better                            0.652092
# Check skills/capacity of developers                                   0.843411
# plan more developers for the user story                               0.863646
# Refine user stories before adding to backlog                          0.681155
# Review planning process                                               0.592753
# Take fewer requests in the Product Backlog                            0.384401
# Check skills/capacity of developers                                   0.080950
# plan more developers for the user story                               0.516966
# Prune and keep product backlog clean: review ne...                    0.009338
# Decrease number of WIPs to under …                                    0.674359
# Formulate and estimate user stories better                            0.191652
# Check skills/capacity of developers                                   0.996804
# Check foundational processes, platforms and aut...                    0.492845
# Use Git more actively                                                 0.663568
# Plan smaller tasks (<1 day) and PRs                                   0.942572
# Prioritize fixing broken build                                        0.414674
# Optimize build / test time                                            0.311066
# Run static code analysis on daily basis                               0.112809
# Integrate code more frequently                                        0.286863
# Write more unit tests                                                 0.046395
# Act to prevent broken builds                                          0.576429
# Take care of reported defects quickly                                 0.611319
# Increase capacity of the team                                         0.034328
# Check the change integration process: automated...                    0.643708
# Prioritize code review                                                0.179871
# Plan more reviewers                                                   0.970090
# Keep PR WIP stable to avoid PR saturation                             0.671547
# Investigate impediments against deployment proc...                    0.564738
# Align team discussions, don’t waste too much ti...                    0.634171
# Foster the culture of code review                                     0.659082
# Try to optimize deployment time                                       0.685269
# Investigate deployment pipeline                                       0.018574
# Deploy PRs more often                                                 0.230463
#
#                                                     Build Frequency   \
# Take fewer requests in the Product Backlog                  0.469330
# Finish old user stories first                               0.567434
# Refine user stories before adding to backlog                0.534800
# Formulate and estimate user stories better                  0.502261
# Check skills/capacity of developers                         0.188924
# plan more developers for the user story                     0.268398
# Refine user stories before adding to backlog                0.573053
# Review planning process                                     0.075826
# Take fewer requests in the Product Backlog                  0.032270
# Check skills/capacity of developers                         0.261733
# plan more developers for the user story                     0.029747
# Prune and keep product backlog clean: review ne...          0.630135
# Decrease number of WIPs to under …                          0.576605
# Formulate and estimate user stories better                  0.530967
# Check skills/capacity of developers                         0.994794
# Check foundational processes, platforms and aut...          0.200939
# Use Git more actively                                       0.632888
# Plan smaller tasks (<1 day) and PRs                         0.717665
# Prioritize fixing broken build                              0.369317
# Optimize build / test time                                  0.700722
# Run static code analysis on daily basis                     0.733918
# Integrate code more frequently                              0.013233
# Write more unit tests                                       0.962483
# Act to prevent broken builds                                0.506789
# Take care of reported defects quickly                       0.633108
# Increase capacity of the team                               0.592575
# Check the change integration process: automated...          0.030289
# Prioritize code review                                      0.309070
# Plan more reviewers                                         0.996489
# Keep PR WIP stable to avoid PR saturation                   0.253427
# Investigate impediments against deployment proc...          0.896516
# Align team discussions, don’t waste too much ti...          0.042640
# Foster the culture of code review                           0.527962
# Try to optimize deployment time                             0.629018
# Investigate deployment pipeline                             0.436010
# Deploy PRs more often                                       0.239388
#
#                                                     Average Time to Fix Broken Build   \
# Take fewer requests in the Product Backlog                                   0.043087
# Finish old user stories first                                                0.489914
# Refine user stories before adding to backlog                                 0.645357
# Formulate and estimate user stories better                                   0.650057
# Check skills/capacity of developers                                          0.389958
# plan more developers for the user story                                      0.969782
# Refine user stories before adding to backlog                                 0.483101
# Review planning process                                                      0.625978
# Take fewer requests in the Product Backlog                                   0.612786
# Check skills/capacity of developers                                          0.128782
# plan more developers for the user story                                      0.347509
# Prune and keep product backlog clean: review ne...                           0.610510
# Decrease number of WIPs to under …                                           0.793984
# Formulate and estimate user stories better                                   0.367588
# Check skills/capacity of developers                                          0.003591
# Check foundational processes, platforms and aut...                           0.763378
# Use Git more actively                                                        0.322105
# Plan smaller tasks (<1 day) and PRs                                          0.868313
# Prioritize fixing broken build                                               0.105327
# Optimize build / test time                                                   0.598247
# Run static code analysis on daily basis                                      0.505924
# Integrate code more frequently                                               0.905837
# Write more unit tests                                                        0.404130
# Act to prevent broken builds                                                 0.631747
# Take care of reported defects quickly                                        0.562901
# Increase capacity of the team                                                0.234280
# Check the change integration process: automated...                           0.086144
# Prioritize code review                                                       0.268530
# Plan more reviewers                                                          0.161220
# Keep PR WIP stable to avoid PR saturation                                    0.931023
# Investigate impediments against deployment proc...                           0.195104
# Align team discussions, don’t waste too much ti...                           0.063438
# Foster the culture of code review                                            0.561215
# Try to optimize deployment time                                              0.601732
# Investigate deployment pipeline                                              0.344632
# Deploy PRs more often                                                        0.818687
#
#                                                     Average Build Execution Time   \
# Take fewer requests in the Product Backlog                               0.974056
# Finish old user stories first                                            0.646672
# Refine user stories before adding to backlog                             0.408556
# Formulate and estimate user stories better                               0.972188
# Check skills/capacity of developers                                      0.766596
# plan more developers for the user story                                  0.062144
# Refine user stories before adding to backlog                             0.102957
# Review planning process                                                  0.405425
# Take fewer requests in the Product Backlog                               0.059022
# Check skills/capacity of developers                                      0.192218
# plan more developers for the user story                                  0.589700
# Prune and keep product backlog clean: review ne...                       0.146930
# Decrease number of WIPs to under …                                       0.871551
# Formulate and estimate user stories better                               0.868725
# Check skills/capacity of developers                                      0.486247
# Check foundational processes, platforms and aut...                       0.109639
# Use Git more actively                                                    0.273326
# Plan smaller tasks (<1 day) and PRs                                      0.959025
# Prioritize fixing broken build                                           0.370787
# Optimize build / test time                                               0.188092
# Run static code analysis on daily basis                                  0.619646
# Integrate code more frequently                                           0.155157
# Write more unit tests                                                    0.460623
# Act to prevent broken builds                                             0.265660
# Take care of reported defects quickly                                    0.974099
# Increase capacity of the team                                            0.098489
# Check the change integration process: automated...                       0.458383
# Prioritize code review                                                   0.178288
# Plan more reviewers                                                      0.932775
# Keep PR WIP stable to avoid PR saturation                                0.463172
# Investigate impediments against deployment proc...                       0.981523
# Align team discussions, don’t waste too much ti...                       0.689221
# Foster the culture of code review                                        0.710427
# Try to optimize deployment time                                          0.084535
# Investigate deployment pipeline                                          0.866358
# Deploy PRs more often                                                    0.432433
#
#                                                     ...  \
# Take fewer requests in the Product Backlog          ...
# Finish old user stories first                       ...
# Refine user stories before adding to backlog        ...
# Formulate and estimate user stories better          ...
# Check skills/capacity of developers                 ...
# plan more developers for the user story             ...
# Refine user stories before adding to backlog        ...
# Review planning process                             ...
# Take fewer requests in the Product Backlog          ...
# Check skills/capacity of developers                 ...
# plan more developers for the user story             ...
# Prune and keep product backlog clean: review ne...  ...
# Decrease number of WIPs to under …                  ...
# Formulate and estimate user stories better          ...
# Check skills/capacity of developers                 ...
# Check foundational processes, platforms and aut...  ...
# Use Git more actively                               ...
# Plan smaller tasks (<1 day) and PRs                 ...
# Prioritize fixing broken build                      ...
# Optimize build / test time                          ...
# Run static code analysis on daily basis             ...
# Integrate code more frequently                      ...
# Write more unit tests                               ...
# Act to prevent broken builds                        ...
# Take care of reported defects quickly               ...
# Increase capacity of the team                       ...
# Check the change integration process: automated...  ...
# Prioritize code review                              ...
# Plan more reviewers                                 ...
# Keep PR WIP stable to avoid PR saturation           ...
# Investigate impediments against deployment proc...  ...
# Align team discussions, don’t waste too much ti...  ...
# Foster the culture of code review                   ...
# Try to optimize deployment time                     ...
# Investigate deployment pipeline                     ...
# Deploy PRs more often                               ...
#
#                                                     Average Pull Request Lead Time   \
# Take fewer requests in the Product Backlog                                 0.309828
# Finish old user stories first                                              0.306479
# Refine user stories before adding to backlog                               0.266006
# Formulate and estimate user stories better                                 0.388200
# Check skills/capacity of developers                                        0.343605
# plan more developers for the user story                                    0.892276
# Refine user stories before adding to backlog                               0.986787
# Review planning process                                                    0.360031
# Take fewer requests in the Product Backlog                                 0.577532
# Check skills/capacity of developers                                        0.004974
# plan more developers for the user story                                    0.579871
# Prune and keep product backlog clean: review ne...                         0.155687
# Decrease number of WIPs to under …                                         0.323493
# Formulate and estimate user stories better                                 0.622190
# Check skills/capacity of developers                                        0.398731
# Check foundational processes, platforms and aut...                         0.360033
# Use Git more actively                                                      0.159259
# Plan smaller tasks (<1 day) and PRs                                        0.279544
# Prioritize fixing broken build                                             0.091456
# Optimize build / test time                                                 0.528146
# Run static code analysis on daily basis                                    0.946827
# Integrate code more frequently                                             0.600366
# Write more unit tests                                                      0.328689
# Act to prevent broken builds                                               0.640931
# Take care of reported defects quickly                                      0.847552
# Increase capacity of the team                                              0.001960
# Check the change integration process: automated...                         0.945806
# Prioritize code review                                                     0.943116
# Plan more reviewers                                                        0.621438
# Keep PR WIP stable to avoid PR saturation                                  0.135139
# Investigate impediments against deployment proc...                         0.454506
# Align team discussions, don’t waste too much ti...                         0.582683
# Foster the culture of code review                                          0.357991
# Try to optimize deployment time                                            0.912195
# Investigate deployment pipeline                                            0.697416
# Deploy PRs more often                                                      0.439953
#
#                                                     Average Code Review Time   \
# Take fewer requests in the Product Backlog                           0.776777
# Finish old user stories first                                        0.441402
# Refine user stories before adding to backlog                         0.101162
# Formulate and estimate user stories better                           0.527174
# Check skills/capacity of developers                                  0.446786
# plan more developers for the user story                              0.019898
# Refine user stories before adding to backlog                         0.470038
# Review planning process                                              0.158155
# Take fewer requests in the Product Backlog                           0.891819
# Check skills/capacity of developers                                  0.221318
# plan more developers for the user story                              0.776787
# Prune and keep product backlog clean: review ne...                   0.007037
# Decrease number of WIPs to under …                                   0.207596
# Formulate and estimate user stories better                           0.089643
# Check skills/capacity of developers                                  0.080052
# Check foundational processes, platforms and aut...                   0.918034
# Use Git more actively                                                0.648608
# Plan smaller tasks (<1 day) and PRs                                  0.653594
# Prioritize fixing broken build                                       0.325266
# Optimize build / test time                                           0.830716
# Run static code analysis on daily basis                              0.307125
# Integrate code more frequently                                       0.731794
# Write more unit tests                                                0.587709
# Act to prevent broken builds                                         0.625239
# Take care of reported defects quickly                                0.261689
# Increase capacity of the team                                        0.006580
# Check the change integration process: automated...                   0.626320
# Prioritize code review                                               0.971031
# Plan more reviewers                                                  0.102726
# Keep PR WIP stable to avoid PR saturation                            0.918787
# Investigate impediments against deployment proc...                   0.057748
# Align team discussions, don’t waste too much ti...                   0.543142
# Foster the culture of code review                                    0.891770
# Try to optimize deployment time                                      0.488914
# Investigate deployment pipeline                                      0.155617
# Deploy PRs more often                                                0.844103
#
#                                                     Average Pull Request Time to First Review   \
# Take fewer requests in the Product Backlog                                            0.899107
# Finish old user stories first                                                         0.630555
# Refine user stories before adding to backlog                                          0.005449
# Formulate and estimate user stories better                                            0.633438
# Check skills/capacity of developers                                                   0.492824
# plan more developers for the user story                                               0.848040
# Refine user stories before adding to backlog                                          0.464291
# Review planning process                                                               0.778723
# Take fewer requests in the Product Backlog                                            0.830077
# Check skills/capacity of developers                                                   0.820223
# plan more developers for the user story                                               0.707225
# Prune and keep product backlog clean: review ne...                                    0.420176
# Decrease number of WIPs to under …                                                    0.658269
# Formulate and estimate user stories better                                            0.373620
# Check skills/capacity of developers                                                   0.187378
# Check foundational processes, platforms and aut...                                    0.979342
# Use Git more actively                                                                 0.844482
# Plan smaller tasks (<1 day) and PRs                                                   0.506860
# Prioritize fixing broken build                                                        0.982548
# Optimize build / test time                                                            0.616407
# Run static code analysis on daily basis                                               0.841274
# Integrate code more frequently                                                        0.380750
# Write more unit tests                                                                 0.462714
# Act to prevent broken builds                                                          0.452687
# Take care of reported defects quickly                                                 0.912740
# Increase capacity of the team                                                         0.296982
# Check the change integration process: automated...                                    0.239500
# Prioritize code review                                                                0.250818
# Plan more reviewers                                                                   0.886588
# Keep PR WIP stable to avoid PR saturation                                             0.588153
# Investigate impediments against deployment proc...                                    0.352180
# Align team discussions, don’t waste too much ti...                                    0.420571
# Foster the culture of code review                                                     0.131712
# Try to optimize deployment time                                                       0.043237
# Investigate deployment pipeline                                                       0.475640
# Deploy PRs more often                                                                 0.836380
#
#                                                     Average Pull Request Last Review to Merge Time   \
# Take fewer requests in the Product Backlog                                                 0.578855
# Finish old user stories first                                                              0.638129
# Refine user stories before adding to backlog                                               0.624043
# Formulate and estimate user stories better                                                 0.972355
# Check skills/capacity of developers                                                        0.398118
# plan more developers for the user story                                                    0.531805
# Refine user stories before adding to backlog                                               0.299081
# Review planning process                                                                    0.039969
# Take fewer requests in the Product Backlog                                                 0.699654
# Check skills/capacity of developers                                                        0.423465
# plan more developers for the user story                                                    0.992605
# Prune and keep product backlog clean: review ne...                                         0.841328
# Decrease number of WIPs to under …                                                         0.869883
# Formulate and estimate user stories better                                                 0.512533
# Check skills/capacity of developers                                                        0.607329
# Check foundational processes, platforms and aut...                                         0.295443
# Use Git more actively                                                                      0.057650
# Plan smaller tasks (<1 day) and PRs                                                        0.657924
# Prioritize fixing broken build                                                             0.021668
# Optimize build / test time                                                                 0.131347
# Run static code analysis on daily basis                                                    0.912278
# Integrate code more frequently                                                             0.236271
# Write more unit tests                                                                      0.842170
# Act to prevent broken builds                                                               0.168719
# Take care of reported defects quickly                                                      0.289948
# Increase capacity of the team                                                              0.764222
# Check the change integration process: automated...                                         0.815685
# Prioritize code review                                                                     0.209441
# Plan more reviewers                                                                        0.004329
# Keep PR WIP stable to avoid PR saturation                                                  0.040811
# Investigate impediments against deployment proc...                                         0.606566
# Align team discussions, don’t waste too much ti...                                         0.209919
# Foster the culture of code review                                                          0.580957
# Try to optimize deployment time                                                            0.961975
# Investigate deployment pipeline                                                            0.287260
# Deploy PRs more often                                                                      0.381508
#
#                                                     Pull Request Flow Ratio  \
# Take fewer requests in the Product Backlog                         0.146891
# Finish old user stories first                                      0.005930
# Refine user stories before adding to backlog                       0.199320
# Formulate and estimate user stories better                         0.023766
# Check skills/capacity of developers                                0.389931
# plan more developers for the user story                            0.593639
# Refine user stories before adding to backlog                       0.170161
# Review planning process                                            0.389220
# Take fewer requests in the Product Backlog                         0.533159
# Check skills/capacity of developers                                0.584555
# plan more developers for the user story                            0.980310
# Prune and keep product backlog clean: review ne...                 0.513250
# Decrease number of WIPs to under …                                 0.629542
# Formulate and estimate user stories better                         0.238969
# Check skills/capacity of developers                                0.117061
# Check foundational processes, platforms and aut...                 0.470777
# Use Git more actively                                              0.546916
# ...
# Integrate code more frequently                                     0.189949
# Write more unit tests                                              0.470000
# Act to prevent broken builds                                       0.449074
# Take care of reported defects quickly                              0.951282
# Increase capacity of the team                                      0.868159
# Check the change integration process: automated...                 0.766240
# Prioritize code review                                             0.552877
# Plan more reviewers                                                0.157937
# Keep PR WIP stable to avoid PR saturation                          0.023738
# Investigate impediments against deployment proc...                 0.139111
# Align team discussions, don’t waste too much ti...                 0.671019
# Foster the culture of code review                                  0.279846
# Try to optimize deployment time                                    0.069270
# Investigate deployment pipeline                                    0.957044
# Deploy PRs more often                                              0.383725
#
#                                                     Pull Request Engagement  \
# Take fewer requests in the Product Backlog                         0.992440
# Finish old user stories first                                      0.464659
# Refine user stories before adding to backlog                       0.085323
# Formulate and estimate user stories better                         0.385964
# Check skills/capacity of developers                                0.416680
# plan more developers for the user story                            0.260847
# Refine user stories before adding to backlog                       0.495125
# Review planning process                                            0.386216
# Take fewer requests in the Product Backlog                         0.689766
# Check skills/capacity of developers                                0.181908
# plan more developers for the user story                            0.185995
# Prune and keep product backlog clean: review ne...                 0.173311
# Decrease number of WIPs to under …                                 0.010513
# Formulate and estimate user stories better                         0.053349
# Check skills/capacity of developers                                0.788735
# Check foundational processes, platforms and aut...                 0.913730
# Use Git more actively                                              0.221463
# Plan smaller tasks (<1 day) and PRs                                0.759691
# Prioritize fixing broken build                                     0.430882
# Optimize build / test time                                         0.107426
# Run static code analysis on daily basis                            0.912182
# Integrate code more frequently                                     0.585124
# Write more unit tests                                              0.881222
# Act to prevent broken builds                                       0.045534
# Take care of reported defects quickly                              0.884427
# Increase capacity of the team                                      0.002658
# Check the change integration process: automated...                 0.200130
# Prioritize code review                                             0.754133
# Plan more reviewers                                                0.260040
# Keep PR WIP stable to avoid PR saturation                          0.051115
# Investigate impediments against deployment proc...                 0.938685
# Align team discussions, don’t waste too much ti...                 0.044280
# Foster the culture of code review                                  0.825621
# Try to optimize deployment time                                    0.138739
# Investigate deployment pipeline                                    0.766081
# Deploy PRs more often                                              0.190352
#
#                                                     Deployment Volume  \
# Take fewer requests in the Product Backlog                   0.363306
# Finish old user stories first                                0.898594
# Refine user stories before adding to backlog                 0.419674
# Formulate and estimate user stories better                   0.944271
# Check skills/capacity of developers                          0.805861
# plan more developers for the user story                      0.812743
# Refine user stories before adding to backlog                 0.190659
# Review planning process                                      0.725205
# Take fewer requests in the Product Backlog                   0.409621
# Check skills/capacity of developers                          0.023125
# plan more developers for the user story                      0.551649
# Prune and keep product backlog clean: review ne...           0.533686
# Decrease number of WIPs to under …                           0.605794
# Formulate and estimate user stories better                   0.605009
# Check skills/capacity of developers                          0.831154
# Check foundational processes, platforms and aut...           0.084666
# Use Git more actively                                        0.636578
# Plan smaller tasks (<1 day) and PRs                          0.444505
# Prioritize fixing broken build                               0.166392
# Optimize build / test time                                   0.478677
# Run static code analysis on daily basis                      0.643331
# Integrate code more frequently                               0.878671
# Write more unit tests                                        0.206287
# Act to prevent broken builds                                 0.422363
# Take care of reported defects quickly                        0.583833
# Increase capacity of the team                                0.114165
# Check the change integration process: automated...           0.682100
# Prioritize code review                                       0.249985
# Plan more reviewers                                          0.806022
# Keep PR WIP stable to avoid PR saturation                    0.340700
# Investigate impediments against deployment proc...           0.929479
# Align team discussions, don’t waste too much ti...           0.152464
# Foster the culture of code review                            0.888353
# Try to optimize deployment time                              0.645109
# Investigate deployment pipeline                              0.465636
# Deploy PRs more often                                        0.981276
#
#                                                     Average Deployment Duration  \
# Take fewer requests in the Product Backlog                             0.195363
# Finish old user stories first                                          0.445006
# Refine user stories before adding to backlog                           0.907894
# Formulate and estimate user stories better                             0.941861
# Check skills/capacity of developers                                    0.688303
# plan more developers for the user story                                0.572849
# Refine user stories before adding to backlog                           0.760636
# Review planning process                                                0.638317
# Take fewer requests in the Product Backlog                             0.449519
# Check skills/capacity of developers                                    0.234782
# plan more developers for the user story                                0.189311
# Prune and keep product backlog clean: review ne...                     0.127523
# Decrease number of WIPs to under …                                     0.155507
# Formulate and estimate user stories better                             0.376689
# Check skills/capacity of developers                                    0.742736
# Check foundational processes, platforms and aut...                     0.583222
# Use Git more actively                                                  0.962927
# Plan smaller tasks (<1 day) and PRs                                    0.899331
# Prioritize fixing broken build                                         0.372785
# Optimize build / test time                                             0.823715
# Run static code analysis on daily basis                                0.493722
# Integrate code more frequently                                         0.550854
# Write more unit tests                                                  0.125037
# Act to prevent broken builds                                           0.995358
# Take care of reported defects quickly                                  0.745807
# Increase capacity of the team                                          0.318016
# Check the change integration process: automated...                     0.065120
# Prioritize code review                                                 0.604055
# Plan more reviewers                                                    0.602628
# Keep PR WIP stable to avoid PR saturation                              0.690093
# Investigate impediments against deployment proc...                     0.558709
# Align team discussions, don’t waste too much ti...                     0.668959
# Foster the culture of code review                                      0.368887
# Try to optimize deployment time                                        0.361879
# Investigate deployment pipeline                                        0.397905
# Deploy PRs more often                                                  0.756753
#
#                                                     Deployment Failure Rate  \
# Take fewer requests in the Product Backlog                         0.238310
# Finish old user stories first                                      0.718624
# Refine user stories before adding to backlog                       0.046882
# Formulate and estimate user stories better                         0.758441
# Check skills/capacity of developers                                0.892919
# plan more developers for the user story                            0.754782
# Refine user stories before adding to backlog                       0.968947
# Review planning process                                            0.068240
# Take fewer requests in the Product Backlog                         0.260006
# Check skills/capacity of developers                                0.561519
# plan more developers for the user story                            0.605166
# Prune and keep product backlog clean: review ne...                 0.028716
# Decrease number of WIPs to under …                                 0.490317
# Formulate and estimate user stories better                         0.398851
# Check skills/capacity of developers                                0.747220
# Check foundational processes, platforms and aut...                 0.226005
# Use Git more actively                                              0.617150
# Plan smaller tasks (<1 day) and PRs                                0.744819
# Prioritize fixing broken build                                     0.457086
# Optimize build / test time                                         0.535670
# Run static code analysis on daily basis                            0.518980
# Integrate code more frequently                                     0.854532
# Write more unit tests                                              0.725806
# Act to prevent broken builds                                       0.438953
# Take care of reported defects quickly                              0.293745
# Increase capacity of the team                                      0.710571
# Check the change integration process: automated...                 0.569989
# Prioritize code review                                             0.564880
# Plan more reviewers                                                0.604728
# Keep PR WIP stable to avoid PR saturation                          0.332375
# Investigate impediments against deployment proc...                 0.109082
# Align team discussions, don’t waste too much ti...                 0.393223
# Foster the culture of code review                                  0.111229
# Try to optimize deployment time                                    0.414836
# Investigate deployment pipeline                                    0.429371
# Deploy PRs more often                                              0.921821
#
#                                                     Pull Request/Deployment Ratio
# Take fewer requests in the Product Backlog                               0.022030
# Finish old user stories first                                            0.407638
# Refine user stories before adding to backlog                             0.597400
# Formulate and estimate user stories better                               0.278638
# Check skills/capacity of developers                                      0.464003
# plan more developers for the user story                                  0.303476
# Refine user stories before adding to backlog                             0.666956
# Review planning process                                                  0.002694
# Take fewer requests in the Product Backlog                               0.901126
# Check skills/capacity of developers                                      0.761469
# plan more developers for the user story                                  0.430814
# Prune and keep product backlog clean: review ne...                       0.273970
# Decrease number of WIPs to under …                                       0.514793
# Formulate and estimate user stories better                               0.437495
# Check skills/capacity of developers                                      0.393914
# Check foundational processes, platforms and aut...                       0.280130
# Use Git more actively                                                    0.867870
# Plan smaller tasks (<1 day) and PRs                                      0.614588
# Prioritize fixing broken build                                           0.310224
# Optimize build / test time                                               0.853382
# Run static code analysis on daily basis                                  0.908114
# Integrate code more frequently                                           0.166881
# Write more unit tests                                                    0.080404
# Act to prevent broken builds                                             0.251466
# Take care of reported defects quickly                                    0.264986
# Increase capacity of the team                                            0.556708
# Check the change integration process: automated...                       0.686279
# Prioritize code review                                                   0.818013
# Plan more reviewers                                                      0.084625
# Keep PR WIP stable to avoid PR saturation                                0.137784
# Investigate impediments against deployment proc...                       0.265929
# Align team discussions, don’t waste too much ti...                       0.030394
# Foster the culture of code review                                        0.857612
# Try to optimize deployment time                                          0.521267
# Investigate deployment pipeline                                          0.422620
# Deploy PRs more often                                                    0.671374
#
# [36 rows x 27 columns]

# %%
res = [give_recommendation_based_on_correlation_matrix(matrix.tolist(),row.to_list()) for i,row in df.iterrows()]
df["top 1 recommendation"] = res

df
# Out:
#      Average Throughput Rate   Average Lead Time for User Story   \
# 0                    0.379975                           0.893063
# 1                    0.117617                           0.313686
# 2                    0.187721                           0.360067
# 3                    0.158738                           0.988420
# 4                    0.875645                           0.546871
# ..                        ...                                ...
# 145                  0.629347                           0.648760
# 146                  0.699009                           0.363002
# 147                  0.927469                           0.248661
# 148                  0.097408                           0.950892
# 149                  0.954573                           0.195016
#
#      Average Cycle Time for User Story   Average Wait Time for User Story   \
# 0                              0.016876                           0.547785
# 1                              0.703464                           0.938548
# 2                              0.314391                           0.518821
# 3                              0.188884                           0.979928
# 4                              0.942359                           0.166274
# ..                                  ...                                ...
# 145                            0.431498                           0.048893
# 146                            0.608967                           0.013290
# 147                            0.805686                           0.944539
# 148                            0.434899                           0.273746
# 149                            0.563263                           0.726887
#
#      Amount of WIP   Average Repository Activity   Average Pull Request Size   \
# 0          0.086195                      0.099256                    0.276041
# 1          0.558001                      0.491532                    0.126450
# 2          0.352522                      0.600092                    0.234122
# 3          0.758915                      0.283366                    0.775372
# 4          0.642098                      0.419629                    0.078844
# ..              ...                           ...                         ...
# 145        0.437622                      0.243976                    0.857104
# 146        0.389981                      0.824989                    0.834146
# 147        0.439125                      0.134059                    0.553909
# 148        0.086150                      0.555807                    0.034888
# 149        0.346686                      0.974921                    0.140731
#
#      Build Frequency   Average Time to Fix Broken Build   \
# 0            0.957018                           0.443958
# 1            0.025927                           0.633108
# 2            0.459313                           0.608453
# 3            0.669959                           0.169412
# 4            0.706464                           0.544556
# ..                ...                                ...
# 145          0.926557                           0.377396
# 146          0.995136                           0.971573
# 147          0.294022                           0.693578
# 148          0.326183                           0.101579
# 149          0.916303                           0.631543
#
#      Average Build Execution Time   ...  Average Code Review Time   \
# 0                         0.944336  ...                   0.836003
# 1                         0.647951  ...                   0.915316
# 2                         0.468424  ...                   0.820082
# 3                         0.491021  ...                   0.264485
# 4                         0.934640  ...                   0.897887
# ..                             ...  ...                        ...
# 145                       0.822225  ...                   0.931680
# 146                       0.169881  ...                   0.332741
# 147                       0.554454  ...                   0.995910
# 148                       0.877018  ...                   0.248687
# 149                       0.943466  ...                   0.892361
#
#      Average Pull Request Time to First Review   \
# 0                                      0.840807
# 1                                      0.243466
# 2                                      0.760558
# 3                                      0.946744
# 4                                      0.901057
# ..                                          ...
# 145                                    0.523310
# 146                                    0.363416
# 147                                    0.081929
# 148                                    0.124416
# 149                                    0.261105
#
#      Average Pull Request Last Review to Merge Time   Pull Request Flow Ratio  \
# 0                                           0.049687                 0.917653
# 1                                           0.714299                 0.575168
# 2                                           0.769838                 0.994982
# 3                                           0.899322                 0.254659
# 4                                           0.979984                 0.258993
# ..                                               ...                      ...
# 145                                         0.105522                 0.650079
# 146                                         0.507757                 0.522090
# 147                                         0.215613                 0.576259
# 148                                         0.069024                 0.370502
# 149                                         0.955458                 0.279103
#
#      Pull Request Engagement  Deployment Volume  Average Deployment Duration  \
# 0                   0.348791           0.453165                     0.758890
# 1                   0.028287           0.353625                     0.529983
# 2                   0.123741           0.757098                     0.522323
# 3                   0.207307           0.446430                     0.535928
# 4                   0.075084           0.019225                     0.975817
# ..                       ...                ...                          ...
# 145                 0.056947           0.807030                     0.862246
# 146                 0.810625           0.795249                     0.244872
# 147                 0.667681           0.578423                     0.675320
# 148                 0.753883           0.530452                     0.970238
# 149                 0.158627           0.586511                     0.305521
#
#      Deployment Failure Rate  Pull Request/Deployment Ratio  \
# 0                   0.895446                       0.449831
# 1                   0.574735                       0.744900
# 2                   0.957371                       0.749962
# 3                   0.109710                       0.637266
# 4                   0.569543                       0.814241
# ..                       ...                            ...
# 145                 0.001900                       0.593890
# 146                 0.568989                       0.728315
# 147                 0.037435                       0.689806
# 148                 0.341276                       0.167700
# 149                 0.200386                       0.613549
#
#                            top 1 recommendation
# 0         Take care of reported defects quickly
# 1    Take fewer requests in the Product Backlog
# 2       plan more developers for the user story
# 3                 Finish old user stories first
# 4       Run static code analysis on daily basis
# ..                                          ...
# 145                         Plan more reviewers
# 146             Try to optimize deployment time
# 147                Act to prevent broken builds
# 148               Finish old user stories first
# 149          Decrease number of WIPs to under …
#
# [150 rows x 28 columns]
